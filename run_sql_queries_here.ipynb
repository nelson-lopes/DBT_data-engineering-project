# %%
import duckdb
import pandas as pd

# %%
sql_query = '''
show tables
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#                               name
# 0   bronze_parking_violation_codes
# 1        bronze_parking_violations
# 2                      first_model
# 3              gold_ticket_metrics
# 4            gold_vehicles_metrics
# 5           parking_violation_2023
# 6          parking_violation_codes
# 7                        ref_model
# 8   silver_parking_violation_codes
# 9        silver_parking_violations
# 10        silver_violation_tickets
# 11       silver_violation_vehicles

# %%
sql_query_import_1 = '''
CREATE OR REPLACE TABLE parking_violation_codes AS
SELECT *
FROM read_csv_auto(
  'data/dof_parking_violation_codes.csv',
  normalize_names=True
)
'''

sql_query_import_2 = '''
CREATE OR REPLACE TABLE parking_violation_2023 AS
SELECT *
FROM read_csv_auto(
  'data/parking_violations_issued_fiscal_year_2023_sample.csv',
  normalize_names=True
)
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
  con.sql(sql_query_import_1)
  con.sql(sql_query_import_2)

# %%
sql_query = '''
SELECT * FROM bronze_parking_violation_codes
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#     violation_code  manhattan_96th_st_below                      definition  \
# 0                1                      515   FAILURE TO DISPLAY BUS PERMIT
# 1                2                      515  NO OPERATOR NAM/ADD/PH DISPLAY
# 2                3                      515  UNAUTHORIZED PASSENGER PICK-UP
# 3                4                      115  BUS PARKING IN LOWER MANHATTAN
# 4                5                      250              BUS LANE VIOLATION
# ..             ...                      ...                             ...
# 92              93                       65        REMOVE/REPLACE FLAT TIRE
# 93              96                       95               RAILROAD CROSSING
# 94              97                       65                      VACANT LOT
# 95              98                       95            OBSTRUCTING DRIVEWAY
# 96              99                      105                           OTHER
#
#     all_other_areas
# 0               515
# 1               515
# 2               515
# 3               115
# 4               250
# ..              ...
# 92               65
# 93               95
# 94               45
# 95               95
# 96              105
#
# [97 rows x 4 columns]

# %%
sql_query = '''
SELECT * FROM silver_parking_violations
'''

with duckdb.connect('data/nyc_parking_violations.db') as con:
    display(con.sql(sql_query).df())
# Out:
#        summons_number registration_state plate_type issue_date  \
# 0          9010912681                 CA        PAS 2022-10-11
# 1          4858762841                 NY        PAS 2023-08-21
# 2          4854645684                 FL        PAS 2023-07-26
# 3          9044582707                 NY        PAS 2023-04-10
# 4          9041503330                 NY        PAS 2023-03-21
# ...               ...                ...        ...        ...
# 99995      9069356715                 NY        COM 2023-08-07
# 99996      4802425399                 NY        OMS 2022-09-25
# 99997      4809109689                 NY        ORG 2022-10-28
# 99998      4834558370                 NY        PAS 2023-04-04
# 99999      4837284462                 NY        PAS 2023-04-21
#
#        violation_code vehicle_body_type vehicle_make issuing_agency  \
# 0                  17              SUBN         FORD              T
# 1                  36              4DSD        HONDA              V
# 2                  36                UT          BMW              V
# 3                  21              SUBN        SUBAR              T
# 4                  21              4DSD        CHEVR              T
# ...               ...               ...          ...            ...
# 99995              21               VAN         FORD              T
# 99996              36              SUBN        CHEVR              V
# 99997              36              SUBN        NISSA              V
# 99998              36              4DSD        LEXUS              V
# 99999              36              4DSD          KIA              V
#
#        vehicle_expiration_date  violation_location  ...  issuer_precinct  \
# 0                     20220788                50.0  ...               50
# 1                            0                 NaN  ...                0
# 2                            0                 NaN  ...                0
# 3                     20231217                79.0  ...               79
# 4                     20250320                26.0  ...               26
# ...                        ...                 ...  ...              ...
# 99995                 20240831                30.0  ...               30
# 99996                        0                 NaN  ...                0
# 99997                        0                 NaN  ...                0
# 99998                        0                 NaN  ...                0
# 99999                        0                 NaN  ...                0
#
#        issuer_code  issuer_command issuer_squad violation_time  \
# 0           365910            T201            D          0825A
# 1                0            None         None          1036A
# 2                0            None         None          0126P
# 3           370326            T301            H          0924A
# 4           373097            T103            C          1155A
# ...            ...             ...          ...            ...
# 99995       361887            T103           II          1121A
# 99996            0            None         None          0214P
# 99997            0            None         None          0915A
# 99998            0            None         None          0416P
# 99999            0            None         None          0606P
#
#       violation_county violation_legal_code vehicle_color vehicle_year  \
# 0                   BX                  NaN         BLACK            0
# 1                   BK                 True            GY         2003
# 2                   QN                 True           WHI         2022
# 3                    K                  NaN            GY         2017
# 4                   NY                  NaN            BK         2018
# ...                ...                  ...           ...          ...
# 99995               NY                  NaN            YW         2016
# 99996               BX                 True            WH         2021
# 99997               MN                 True            GY         2020
# 99998               BK                 True            BK         2002
# 99999               ST                 True            WH         2020
#
#        is_manhattan_96th_st_below
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 99995                       False
# 99996                       False
# 99997                        True
# 99998                       False
# 99999                       False
#
# [100000 rows x 21 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
